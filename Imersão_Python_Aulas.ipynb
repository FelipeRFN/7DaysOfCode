# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeRFN/7DaysOfCode/blob/main/Imers%C3%A3o_Python_Aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5  1/26/2024         9.50          5.20          11.76          2.26
# 1  CMIN3  1/26/2024         6.82          2.40           2.40        -12.11
# 2  PETR3  1/26/2024        41.96          2.19           7.73          7.64
# 3  SUZB3  1/26/2024        52.91          2.04           2.14         -4.89
# 4  CPFE3  1/26/2024        37.10          2.03           2.49         -3.66
# 5  PRIO3  1/26/2024        45.69          1.98           2.42         -0.78
# 6  PETR4  1/26/2024        39.96          1.73           6.47          7.30
# 7  VALE3  1/26/2024        69.50          1.66           2.06         -9.97
# 8  MULT3  1/26/2024        28.19          1.58           2.03         -0.81
# 9  ITUB4  1/26/2024        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variação Mês $  \
# 0          2.26         15.97      9.18      9.56  ...   1.208171e+07
# 1        -12.11         50.56      6.66      6.86  ...   2.962008e+08
# 2          7.64         77.55     40.81     42.34  ...   1.160483e+09
# 3         -4.89         18.85     51.89     53.17  ...   1.817597e+08
# 4         -3.66         20.70     36.37     37.32  ...   1.926802e+07
# 5         -0.78          8.08     44.25     45.69  ...   4.351682e+06
# 6          7.30         95.01     38.91     40.09  ...   1.541157e+09
# 7         -9.97        -23.49     67.50     69.81  ...   5.258683e+09
# 8         -0.81         24.02     27.71     28.36  ...   7.787520e+05
# 9         -3.36         34.25     32.35     32.91  ...   2.684074e+08
#
#    Resultado.2  Var. Ano %  Valor Inicial Ano $  Variação Ano $ Resultado.3  \
# 0        Subiu      0.0226             2.210053    1.208171e+07       Subiu
# 1        Subiu     -0.1211           -13.778587    2.962008e+08       Subiu
# 2        Subiu      0.0764             7.097733    1.160483e+09       Subiu
# 3        Subiu     -0.0489            -5.141415    1.817597e+08       Subiu
# 4        Subiu     -0.0366            -3.799045    1.926802e+07       Subiu
# 5        Subiu     -0.0078            -0.786132    4.351682e+06       Subiu
# 6        Subiu      0.0730             6.803355    1.541157e+09       Subiu
# 7        Subiu     -0.0997           -11.074086    5.258683e+09       Subiu
# 8        Subiu     -0.0081            -0.816615    7.787520e+05       Subiu
# 9        Subiu     -0.0336            -3.476821    2.684074e+08       Subiu
#
#   Variação 12M % Valor inicial 12M $  Variação 12M $ Resultado.4
# 0         0.1597           13.770803    5.319632e+08       Subiu
# 1         0.5056           33.581296    3.013991e+09       Subiu
# 2         0.7755           43.677837    7.248844e+10       Subiu
# 3         0.1885           15.860328    2.161372e+09       Subiu
# 4         0.2070           17.149959    4.919433e+08       Subiu
# 5         0.0808            7.475944    4.286912e+08       Subiu
# 6         0.9501           48.720578    1.436424e+11       Subiu
# 7        -0.2349          -30.701869    3.434961e+10       Subiu
# 8         0.2402           19.367844    5.477108e+08       Subiu
# 9         0.3425           25.512104    2.007612e+10       Subiu
#
# [10 rows x 36 columns]

# %%
df_Total_de_acoes = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Total_de_acoes")
df_Total_de_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
df_Ticker = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Ticker")
df_Ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_ChatGPT = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "ChatGPT")
df_ChatGPT.head(10)
# Out:
#          Empresa          Segmento  Idade em anos
# 0       Usiminas        Siderurgia             79
# 1  CSN Mineração        Siderurgia             30
# 2      Petrobras    Petróleo e Gás             70
# 3         Suzano  Papel e Celulose             99
# 4   CPFL Energia           Energia            109
# 5       PetroRio    Petróleo e Gás             13
# 6      Petrobras    Petróleo e Gás             70
# 7           Vale         Mineração             82
# 8      Multiplan  Shopping Centers             49
# 9  Itaú Unibanco          Bancário             16
