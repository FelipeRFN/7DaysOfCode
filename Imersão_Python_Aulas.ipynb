# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeRFN/7DaysOfCode/blob/main/Imers%C3%A3o_Python_Aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2/3 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5  1/26/2024         9.50          5.20          11.76          2.26
# 1  CMIN3  1/26/2024         6.82          2.40           2.40        -12.11
# 2  PETR3  1/26/2024        41.96          2.19           7.73          7.64
# 3  SUZB3  1/26/2024        52.91          2.04           2.14         -4.89
# 4  CPFE3  1/26/2024        37.10          2.03           2.49         -3.66
# 5  PRIO3  1/26/2024        45.69          1.98           2.42         -0.78
# 6  PETR4  1/26/2024        39.96          1.73           6.47          7.30
# 7  VALE3  1/26/2024        69.50          1.66           2.06         -9.97
# 8  MULT3  1/26/2024        28.19          1.58           2.03         -0.81
# 9  ITUB4  1/26/2024        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variação Mês $  \
# 0          2.26         15.97      9.18      9.56  ...    12081712.90
# 1        -12.11         50.56      6.66      6.86  ...   296200817.30
# 2          7.64         77.55     40.81     42.34  ...  1160483192.00
# 3         -4.89         18.85     51.89     53.17  ...   181759686.70
# 4         -3.66         20.70     36.37     37.32  ...    19268022.34
# 5         -0.78          8.08     44.25     45.69  ...     4351681.86
# 6          7.30         95.01     38.91     40.09  ...  1541156878.00
# 7         -9.97        -23.49     67.50     69.81  ...  5258682994.00
# 8         -0.81         24.02     27.71     28.36  ...      778752.01
# 9         -3.36         34.25     32.35     32.91  ...   268407434.50
#
#    Resultado.2  Var. Ano %  Valor Inicial Ano $  Variação Ano $ Resultado.3  \
# 0        Subiu        0.02                 2.21     12081712.90       Subiu
# 1        Subiu       -0.12               -13.78    296200817.30       Subiu
# 2        Subiu        0.08                 7.10   1160483192.00       Subiu
# 3        Subiu       -0.05                -5.14    181759686.70       Subiu
# 4        Subiu       -0.04                -3.80     19268022.34       Subiu
# 5        Subiu       -0.01                -0.79      4351681.86       Subiu
# 6        Subiu        0.07                 6.80   1541156878.00       Subiu
# 7        Subiu       -0.10               -11.07   5258682994.00       Subiu
# 8        Subiu       -0.01                -0.82       778752.01       Subiu
# 9        Subiu       -0.03                -3.48    268407434.50       Subiu
#
#   Variação 12M % Valor inicial 12M $  Variação 12M $ Resultado.4
# 0           0.16               13.77    531963208.40       Subiu
# 1           0.51               33.58   3013991028.00       Subiu
# 2           0.78               43.68  72488440117.00       Subiu
# 3           0.19               15.86   2161372154.00       Subiu
# 4           0.21               17.15    491943280.90       Subiu
# 5           0.08                7.48    428691172.10       Subiu
# 6           0.95               48.72 143642383967.00       Subiu
# 7          -0.23              -30.70  34349605721.00       Subiu
# 8           0.24               19.37    547710806.20       Subiu
# 9           0.34               25.51  20076119159.00       Subiu
#
# [10 rows x 36 columns]

# %%
df_Total_de_acoes = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Total_de_acoes")
df_Total_de_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   235665566.00
# 1  ALOS3   532616595.00
# 2  ALPA4   176733968.00
# 3  ABEV3  4394245879.00
# 4  ARZZ3    62305891.00
# 5  ASAI3  1349217892.00
# 6  AZUL4   327593725.00
# 7  B3SA3  5602790110.00
# 8  BBSE3   671750768.00
# 9  BBDC3  1500728902.00

# %%
df_Ticker = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "Ticker")
df_Ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_ChatGPT = pd.read_excel("/content/Aula_1.xlsx", sheet_name = "ChatGPT")
df_ChatGPT.head(10)
# Out:
#          Empresa          Segmento  Idade em anos
# 0       Usiminas        Siderurgia             79
# 1  CSN Mineração        Siderurgia             30
# 2      Petrobras    Petróleo e Gás             70
# 3         Suzano  Papel e Celulose             99
# 4   CPFL Energia           Energia            109
# 5       PetroRio    Petróleo e Gás             13
# 6      Petrobras    Petróleo e Gás             70
# 7           Vale         Mineração             82
# 8      Multiplan  Shopping Centers             49
# 9  Itaú Unibanco          Bancário             16

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5  1/26/2024         9.50          5.20
# 1   CMIN3  1/26/2024         6.82          2.40
# 2   PETR3  1/26/2024        41.96          2.19
# 3   SUZB3  1/26/2024        52.91          2.04
# 4   CPFE3  1/26/2024        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3  1/26/2024        10.71         -2.45
# 77  BHIA3  1/26/2024         8.70         -2.46
# 78  RENT3  1/26/2024        56.24         -3.63
# 79  CVCB3  1/26/2024         3.07         -4.36
# 80  GOLL4  1/26/2024         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5  1/26/2024         9.50         5.20
# 1   CMIN3  1/26/2024         6.82         2.40
# 2   PETR3  1/26/2024        41.96         2.19
# 3   SUZB3  1/26/2024        52.91         2.04
# 4   CPFE3  1/26/2024        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3  1/26/2024        10.71        -2.45
# 77  BHIA3  1/26/2024         8.70        -2.46
# 78  RENT3  1/26/2024        56.24        -3.63
# 79  CVCB3  1/26/2024         3.07        -4.36
# 80  GOLL4  1/26/2024         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['Valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_Total_de_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial Código  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns='Código')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
df_principal['variacao_rs'] = (df_principal['valor_final'] - df_principal['Valor_inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['resultado'] = df_principal['variacao_rs'].apply(lambda x: 'Subiu' if x>0 else ("Desceu" if x<0 else "Estável"))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns={'Ticker'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 4   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 77  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 78  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 79  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 80  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_ChatGPT, left_on='Nome', right_on='Empresa', how='left')
df_principal = df_principal.drop(columns={'Empresa'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 79  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 80  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 81  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 82  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração        Siderurgia
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 78    533990587  -143635530.57    Desceu  Carrefour Brasil            Varejo
# 79     94843047   -20810240.84    Desceu       Casas Bahia            Varejo
# 80    853202347 -1807432634.46    Desceu          Localiza        Transporte
# 81    525582771   -73557408.06    Desceu               CVC           Turismo
# 82    198184909  -102993202.62    Desceu               GOL           Aviação
#
#     Idade em anos
# 0              79
# 1              30
# 2              70
# 3              70
# 4              99
# ..            ...
# 78             46
# 79             99
# 80             49
# 81             49
# 82             23
#
# [83 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade em anos' : 'idade_anos'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 79  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 80  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 81  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 82  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração        Siderurgia
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 78    533990587  -143635530.57    Desceu  Carrefour Brasil            Varejo
# 79     94843047   -20810240.84    Desceu       Casas Bahia            Varejo
# 80    853202347 -1807432634.46    Desceu          Localiza        Transporte
# 81    525582771   -73557408.06    Desceu               CVC           Turismo
# 82    198184909  -102993202.62    Desceu               GOL           Aviação
#
#     idade_anos
# 0           79
# 1           30
# 2           70
# 3           70
# 4           99
# ..         ...
# 78          46
# 79          99
# 80          49
# 81          49
# 82          23
#
# [83 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['idade_anos'].apply(lambda x: 'Mais de 100' if x>100 else("Menos de 50" if x<50 else "entre 50 e 100"))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3  1/26/2024        10.71        -2.45    -0.02          10.98
# 79  BHIA3  1/26/2024         8.70        -2.46    -0.02           8.92
# 80  RENT3  1/26/2024        56.24        -3.63    -0.04          58.36
# 81  CVCB3  1/26/2024         3.07        -4.36    -0.04           3.21
# 82  GOLL4  1/26/2024         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração        Siderurgia
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 4     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# ..          ...            ...       ...               ...               ...
# 78    533990587  -143635530.57    Desceu  Carrefour Brasil            Varejo
# 79     94843047   -20810240.84    Desceu       Casas Bahia            Varejo
# 80    853202347 -1807432634.46    Desceu          Localiza        Transporte
# 81    525582771   -73557408.06    Desceu               CVC           Turismo
# 82    198184909  -102993202.62    Desceu               GOL           Aviação
#
#     idade_anos       Cat_idade
# 0           79  entre 50 e 100
# 1           30     Menos de 50
# 2           70  entre 50 e 100
# 3           70  entre 50 e 100
# 4           99  entre 50 e 100
# ..         ...             ...
# 78          46     Menos de 50
# 79          99  entre 50 e 100
# 80          49     Menos de 50
# 81          49     Menos de 50
# 82          23     Menos de 50
#
# [83 rows x 13 columns]

# %%
maior = df_principal['variacao_rs'].max()
menor = df_principal['variacao_rs'].min()
media = df_principal['variacao_rs'].mean()
media_subiu = df_principal[df_principal['resultado'] =='Subiu']['variacao_rs'].mean()
media_desceu = df_principal[df_principal['resultado'] == "Desceu"]['variacao_rs'].mean()

print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Media\tR$ {media:,.2f}")
print(f"Media de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Media de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Media	R$ 224,380,755.83
# Media de quem subiu	R$ 542,661,362.93
# Media de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5  1/26/2024         9.50         5.20     0.05           9.03
# 1   CMIN3  1/26/2024         6.82         2.40     0.02           6.66
# 2   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 3   PETR3  1/26/2024        41.96         2.19     0.02          41.06
# 4   SUZB3  1/26/2024        52.91         2.04     0.02          51.85
# 5   CPFE3  1/26/2024        37.10         2.03     0.02          36.36
# 6   PRIO3  1/26/2024        45.69         1.98     0.02          44.80
# 7   PETR4  1/26/2024        39.96         1.73     0.02          39.28
# 8   PETR4  1/26/2024        39.96         1.73     0.02          39.28
# 9   VALE3  1/26/2024        69.50         1.66     0.02          68.37
# 10  MULT3  1/26/2024        28.19         1.58     0.02          27.75
# 11  ITUB4  1/26/2024        32.81         1.48     0.01          32.33
# 12  RDOR3  1/26/2024        27.56         1.43     0.01          27.17
# 13  BRKM5  1/26/2024        18.55         1.42     0.01          18.29
# 14  AZUL4  1/26/2024        14.27         1.42     0.01          14.07
# 15  RRRP3  1/26/2024        28.75         1.41     0.01          28.35
# 16  EQTL3  1/26/2024        35.32         1.34     0.01          34.85
# 17  CSNA3  1/26/2024        18.16         1.33     0.01          17.92
# 18  YDUQ3  1/26/2024        19.77         1.28     0.01          19.52
# 19  UGPA3  1/26/2024        28.31         1.28     0.01          27.95
# 20  MRVE3  1/26/2024         8.08         1.25     0.01           7.98
# 21  ARZZ3  1/26/2024        57.91         1.15     0.01          57.25
# 22  BBDC4  1/26/2024        15.52         1.04     0.01          15.36
# 23  BEEF3  1/26/2024         7.19         0.98     0.01           7.12
# 24  PCAR3  1/26/2024         4.14         0.97     0.01           4.10
# 25  BRFS3  1/26/2024        14.61         0.96     0.01          14.47
# 26  VIVT3  1/26/2024        51.20         0.88     0.01          50.75
# 27  RAIL3  1/26/2024        22.64         0.84     0.01          22.45
# 28  CIEL3  1/26/2024         4.90         0.82     0.01           4.86
# 29  DXCO3  1/26/2024         7.81         0.77     0.01           7.75
# 30  TIMS3  1/26/2024        17.52         0.74     0.01          17.39
# 31  BRAP4  1/26/2024        23.22         0.73     0.01          23.05
# 32  LWSA3  1/26/2024         5.55         0.72     0.01           5.51
# 33  RECV3  1/26/2024        23.83         0.71     0.01          23.66
# 34  ITSA4  1/26/2024        10.01         0.70     0.01           9.94
# 35  BBAS3  1/26/2024        56.97         0.68     0.01          56.59
# 36  RADL3  1/26/2024        26.16         0.61     0.01          26.00
# 37  GOAU4  1/26/2024        10.08         0.59     0.01          10.02
# 38  CSAN3  1/26/2024        18.57         0.59     0.01          18.46
# 39  JBSS3  1/26/2024        24.34         0.57     0.01          24.20
# 40  MGLU3  1/26/2024         2.08         0.48     0.00           2.07
# 41  BBDC3  1/26/2024        13.75         0.36     0.00          13.70
# 42  GGBR4  1/26/2024        21.84         0.27     0.00          21.78
# 43  RAIZ4  1/26/2024         3.74         0.26     0.00           3.73
# 44  CPLE6  1/26/2024        10.07         0.19     0.00          10.05
# 45  VAMO3  1/26/2024         8.18         0.12     0.00           8.17
#
#     qtd_teorica   variacao_rs resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3    2379877655 2140059393.53     Subiu             Petrobras
# 4     683452836  722946282.71     Subiu                Suzano
# 5     187732538  138573955.06     Subiu          CPFL Energia
# 6     800010734  709687498.18     Subiu              PetroRio
# 7    4566445852 3103136291.22     Subiu             Petrobras
# 8    4566445852 3103136291.22     Subiu             Petrobras
# 9    4196924316 4762926995.25     Subiu                  Vale
# 10    268505432  117732680.08     Subiu             Multiplan
# 11   4801593832 2297591984.33     Subiu         Itaú Unibanco
# 12   1168230366  453917907.01     Subiu             Rede D'Or
# 13    265877867   69054317.64     Subiu               Braskem
# 14    327593725   65452205.55     Subiu                  Azul
# 15    235665566   94204643.35     Subiu          3R Petroleum
# 16   1095587251  511671895.45     Subiu    Equatorial Energia
# 17    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 18    289347914   72295838.99     Subiu                 YDUQS
# 19   1086411192  388705223.96     Subiu              Ultrapar
# 20    376187582   37525872.38     Subiu                   MRV
# 21     62305891   41021792.09     Subiu                Arezzo
# 22   5146576868  822148336.41     Subiu        Banco Bradesco
# 23    261036182   18214628.10     Subiu               Minerva
# 24    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 25   1677525446  233045769.57     Subiu                   BRF
# 26    423091712  188965307.06     Subiu                  Vivo
# 27   1218352541  229771333.63     Subiu                  Rumo
# 28   1095462329   43657683.38     Subiu                 Cielo
# 29    302768240   18068446.61     Subiu                 Dexco
# 30    807896814  103972807.37     Subiu                   TIM
# 31    251003438   42238249.54     Subiu             Bradespar
# 32    393173139   15598886.65     Subiu               Locaweb
# 33    275005663   46201006.00     Subiu        PetroRecôncavo
# 34   5372783971  373853994.88     Subiu                Itaúsa
# 35   1420949112  546752087.99     Subiu       Banco do Brasil
# 36   1275798515  202352473.74     Subiu          RaiaDrogasil
# 37    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 38   1168097881  127229653.18     Subiu                 Cosan
# 39   1134986472  156573285.43     Subiu                   JBS
# 40   2867627068   28493619.27     Subiu        Magazine Luiza
# 41   1500728902   74019610.05     Subiu        Banco Bradesco
# 42   1118525506   65779607.10     Subiu                Gerdau
# 43   1193047233   11571106.42     Subiu                Raízen
# 44   1679335290   32069789.50     Subiu                 Copel
# 45    421383330    4131341.16     Subiu           Grupo Vamos
#
#                 Segmento  idade_anos       Cat_idade
# 0             Siderurgia          79  entre 50 e 100
# 1             Siderurgia          30     Menos de 50
# 2         Petróleo e Gás          70  entre 50 e 100
# 3         Petróleo e Gás          70  entre 50 e 100
# 4       Papel e Celulose          99  entre 50 e 100
# 5                Energia         109     Mais de 100
# 6         Petróleo e Gás          13     Menos de 50
# 7         Petróleo e Gás          70  entre 50 e 100
# 8         Petróleo e Gás          70  entre 50 e 100
# 9              Mineração          82  entre 50 e 100
# 10      Shopping Centers          49     Menos de 50
# 11              Bancário          16     Menos de 50
# 12                 Saúde          47     Menos de 50
# 13          Petroquímica          19     Menos de 50
# 14               Aviação          14     Menos de 50
# 15        Petróleo e Gás          12     Menos de 50
# 16               Energia          24     Menos de 50
# 17            Siderurgia          80  entre 50 e 100
# 18              Educação          59  entre 50 e 100
# 19               Energia          84  entre 50 e 100
# 20      Construção Civil          42     Menos de 50
# 21                  Moda          50  entre 50 e 100
# 22              Bancário          89  entre 50 e 100
# 23             Alimentos          31     Menos de 50
# 24                Varejo          76  entre 50 e 100
# 25             Alimentos          84  entre 50 e 100
# 26      Telecomunicações          21     Menos de 50
# 27            Transporte          13     Menos de 50
# 28  Serviços Financeiros          29     Menos de 50
# 29            Tecnologia           7     Menos de 50
# 30      Telecomunicações          30     Menos de 50
# 31              Bancário          20     Menos de 50
# 32            Tecnologia          26     Menos de 50
# 33        Petróleo e Gás          10     Menos de 50
# 34              Bancário          15     Menos de 50
# 35              Bancário         207     Mais de 100
# 36                 Saúde         114     Mais de 100
# 37            Siderurgia         120     Mais de 100
# 38               Energia          89  entre 50 e 100
# 39             Alimentos          68  entre 50 e 100
# 40                Varejo          65  entre 50 e 100
# 41              Bancário          89  entre 50 e 100
# 42            Siderurgia         120     Mais de 100
# 43               Energia          11     Menos de 50
# 44               Energia          68  entre 50 e 100
# 45             Logística          28     Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                 Segmento    variacao_rs
# 0              Alimentos   407833683.09
# 1                Aviação    65452205.55
# 2               Bancário  4156604263.21
# 3       Construção Civil    37525872.38
# 4               Educação    72295838.99
# 5                Energia  1209821623.57
# 6              Logística     4131341.16
# 7              Mineração  4762926995.25
# 8                   Moda    41021792.09
# 9       Papel e Celulose   722946282.71
# 10          Petroquímica    69054317.64
# 11        Petróleo e Gás 11336484517.00
# 12                 Saúde   656270380.75
# 13  Serviços Financeiros    43657683.38
# 14      Shopping Centers   117732680.08
# 15            Siderurgia   667451901.23
# 16            Tecnologia    33667333.26
# 17      Telecomunicações   292938114.42
# 18            Transporte   229771333.63
# 19                Varejo    34834535.50

# %%
df_analise_saldo = df_principal.groupby('resultado')['variacao_rs'].sum().astype(int).reset_index()
df_analise_saldo
# Out:
#   resultado  variacao_rs
# 0    Desceu  -6338819961
# 1   Estável            0
# 2     Subiu  24962422694

# %%
fig = px.bar(df_analise_saldo, x='resultado', y='variacao_rs', text='variacao_rs', title = 'Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3d334cea-fa10-4fc9-b91a-769a06a9bc22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d334cea-fa10-4fc9-b91a-769a06a9bc22")) {                    Plotly.newPlot(                        "3d334cea-fa10-4fc9-b91a-769a06a9bc22",                        [{"alignmentgroup":"True","hovertemplate":"resultado=%{x}\u003cbr\u003evariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.0,0.0,24962422694.0],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961,0,24962422694],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type" ...

# %% [markdown]
# #Desafio#

# %%
fig_2 = px.pie(df_analise_segmento, labels = 'segmento', values ='variacao_rs', title = 'Valores dos Segmentos', hole = 0.5)
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7feae4f0-ec0e-466e-a6e5-d0ace2e01461" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7feae4f0-ec0e-466e-a6e5-d0ace2e01461")) {                    Plotly.newPlot(                        "7feae4f0-ec0e-466e-a6e5-d0ace2e01461",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"variacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","name":"","showlegend":false,"values":[407833683.0924499,65452205.552800186,4156604263.207215,37525872.37728388,72295838.98616095,1209821623.5672965,4131341.15789051,4762926995.24809,41021792.09077153,722946282.7090385,69054317.63603853,11336484517.004236,656270380.7530686,43657683.37554085,117732680.0784251,667451901.230667,33667333.26053947,292938114.42357796,229771333.63468358,34834535.49753806],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line" ...

# %%
df_idade_segmentos = df_principal.groupby('Segmento')['idade_anos'].sum().reset_index()
df_idade_segmentos
# Out:
# <ipython-input-158-34e79e48f1ac>:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# <ipython-input-158-34e79e48f1ac>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                 Segmento  idade_anos
# 0            Agronegócio         119
# 1              Alimentos         245
# 2                Aviação          92
# 3               Bancário         436
# 4       Bolsa de Valores           9
# 5       Construção Civil         140
# 6             Cosméticos          55
# 7               Educação          71
# 8                Energia         662
# 9           Farmacêutica          49
# 10             Logística          28
# 11             Mineração          82
# 12                  Moda         188
# 13      Papel e Celulose          99
# 14              Pet Shop           8
# 15          Petroquímica          19
# 16        Petróleo e Gás         315
# 17            Saneamento          51
# 18                 Saúde         301
# 19               Seguros          90
# 20  Serviços Financeiros          29
# 21      Shopping Centers          49
# 22            Siderurgia         429
# 23            Tecnologia         150
# 24      Telecomunicações          51
# 25            Transporte          86
# 26               Turismo          49
# 27                Varejo         353

# %%
fig_3 = px.bar(df_idade_segmentos, x= 'idade_anos', y= 'Segmento', color= 'idade_anos')
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7599247e-eaaa-4967-8e80-50aa39436c75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7599247e-eaaa-4967-8e80-50aa39436c75")) {                    Plotly.newPlot(                        "7599247e-eaaa-4967-8e80-50aa39436c75",                        [{"alignmentgroup":"True","hovertemplate":"idade_anos=%{marker.color}\u003cbr\u003eSegmento=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[119,245,92,436,9,140,55,71,662,49,28,82,188,99,8,19,315,51,301,90,29,49,429,150,51,86,49,353],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[119,245,92,436,9,140,55,71,662,49,28,82,188,99,8,19,315,51,301,90,29,49,429,150,51,86,49,353],"xaxis":"x","y":["Agroneg\u00f3cio","Alimentos","Avia\u00e7\u00e3o","Banc\u00e1rio","Bolsa de Valores","Constru\u00e7\u00e3o Civil","Cosm\u00e9ticos","Educa\u00e7\u00e3o","Energia","Farmac\u00eautica","Log\u00edstica","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Pet Shop","Petroqu\u00edmica","Petr\u00f3leo e G\u00e1s","Saneamento","Sa\u00fade","Seguros","Servi\u00e7os Financeiros","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte","Turismo","Varejo"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...
